# %%
import sys
sys.path.append('/home/hci-monster-linux/Documents/Hi5/alex_folder/Hi5-data/ViTPose')

# %%
import cv2
import numpy
import os
import matplotlib.pyplot as plt 
import json

# %%
PATH = '/home/hci-monster-linux/Documents/Hi5/alex_folder/Hi5-data/data/onehand10k/Test/source'
OUT = '/home/hci-monster-linux/Documents/Hi5/alex_folder/Hi5-data/data/output/out_img/onehand10k/masked_testing/image_masked/'

# %%
"""
image demo list: 
17

"""
# Out:
# '\nimage demo list: \n17\n\n'

# %%
file = PATH + '/17.jpg'
image = cv2.imread(file)
plt.imshow(image)
cv2.imwrite(OUT+'17_none.jpg', image)
# Out:
# True

# %%
print(image.shape)
# Out:
# (220, 174, 3)

# %%
top_box = cv2.rectangle(image.copy(),(0,0), (220,55), (0,0,0),-1)
plt.imshow(top_box)
cv2.imwrite(OUT+'17_top.jpg', top_box)
# Out:
# True

# %%
right_box = cv2.rectangle(image.copy(), (130,0), (174,220), (0,0,0), -1)
plt.imshow(right_box)
cv2.imwrite(OUT+'17_right.jpg', right_box)
# Out:
# True

# %%
bottom_box = cv2.rectangle(image.copy(), (0,175), (174,220), (0,0,0), -1)
plt.imshow(bottom_box)
cv2.imwrite(OUT+'17_bottom.jpg', bottom_box)
# Out:
# True

# %%
#write json

annotations_path = '/home/hci-monster-linux/Documents/Hi5/alex_folder/Hi5-data/data/output/out_img/onehand10k/masked_testing/image_masked/onehand10k_test.json'
annotation = json.load(open(annotations_path))
print(annotation.keys())

new_json = {}
new_json['info'] = annotation['info']
new_json['licenses'] = annotation['licenses']
new_json['images'] = [{
            "file_name": "17_none.jpg",
            "height": 220,
            "width": 174,
            "id": 0
        },
        {
            "file_name": "17_bottom.jpg",
            "height": 220,
            "width": 174,
            "id": 1
        },
        {
            "file_name": "17_top.jpg",
            "height": 220,
            "width": 174,
            "id": 2
        },
        {
            "file_name": "17_right.jpg",
            "height": 220,
            "width": 174,
            "id": 3
        }
        ]
new_json['annotations'] = [{
            "bbox": [
                -3.6000000000000014,
                -20.4,
                195.20000000000002,
                252.8
            ],
            "keypoints": [
                33,
                178,
                1,
                76,
                185,
                1,
                110,
                168,
                1,
                138,
                154,
                1,
                155,
                144,
                1,
                94,
                122,
                1,
                115,
                92,
                1,
                131,
                69,
                1,
                141,
                52,
                1,
                74,
                109,
                1,
                92,
                76,
                1,
                105,
                47,
                1,
                114,
                27,
                1,
                56,
                107,
                1,
                68,
                77,
                1,
                75,
                50,
                1,
                78,
                28,
                1,
                40,
                115,
                1,
                41,
                89,
                1,
                43,
                70,
                1,
                44,
                51,
                1
            ],
            "category_id": 1,
            "id": 0,
            "image_id": 17,
            "segmentation": [
                [
                    0,
                    24,
                    0,
                    116.0,
                    0,
                    208,
                    77.5,
                    208,
                    155,
                    208,
                    155,
                    116.0,
                    155,
                    24,
                    77.5,
                    24
                ]
            ],
            "iscrowd": 0,
            "area": 28860
        }, {
            "bbox": [
                -3.6000000000000014,
                -20.4,
                195.20000000000002,
                252.8
            ],
